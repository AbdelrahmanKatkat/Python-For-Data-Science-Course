# %% [markdown]
# ## Built in viz

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')

# %%
df1=pd.read_csv('df1',index_col=0)
    # you can identify which col to be index

# %%
df1
    # index is time series here
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df2=pd.read_csv('df2')

# %%
df2
    # index here is just sequential index
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
# Built in visualization
    # You can use two methods:

# %%
    # Method 1
df1['A'].plot.hist(bins=50)
    # pandas can call histplot on it's own
    # Argument can be added to
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
    # Method 2
df1['A'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Examples of Built in

# %%
# histplot

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#  Area plot

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2['a'].plot.area(alpha=0.4)
    # alpha for transperancy
# Out:
# <AxesSubplot:>

# %%
df2.plot.area()
    # you can plot all the areas at once
# Out:
# <AxesSubplot:>

# %%
df2[0:30].plot.area(alpha=0.4)
    # To limit the output data
# Out:
# <AxesSubplot:>

# %%
# bar plot
    # It will take the index as categorical

# %%
df2['a'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
    # To make data stacked over each other
# Out:
# <AxesSubplot:>

# %%
# line plot
    # Relation between two axis x,y

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].plot.line(x=df1.index)
# Out:
# <AxesSubplot:>

# %%
df1['B'].plot.line(x=df1.index,figsize=(12,3),lw=2,ls='--')
    # As it follows matplot you can use figsize
# Out:
# <AxesSubplot:>

# %%
# scatter plot(x,y)

# %%
df1.plot.scatter(x='A',y='B',c='r')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
    # you can define the color based on other column
    # It's a 3D lvl
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*99)
    # You can show another column by size
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
# box plot

# %%
df2.plot.box()
    # column will be categories
    # index will be y axis
# Out:
# <AxesSubplot:>

# %%
df2[['a','b']].plot.box()
# Out:
# <AxesSubplot:>

# %%
# hexbin
    # It's like scatter plot but with hexs

# %%
df=pd.DataFrame(np.random.rand(1000,2),columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0  0.294877  0.019350
# 1  0.459450  0.266574
# 2  0.387619  0.753772
# 3  0.154506  0.635148
# 4  0.218928  0.524677

# %%
df.plot.hexbin(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm')
    # To increase the hex size for grids
    # plots get darkes as you find more data in it
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
# Kernel desity

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Just use them with line plot & hist
