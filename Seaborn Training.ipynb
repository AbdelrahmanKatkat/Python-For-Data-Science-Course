# %%
# Seaborn: is a statistical plotting library
    # It's build on myplotlib
# pip install seaborn
# pip install statsmodels
# It has many features you can find on 
    # https://seaborn.pydata.org/examples/index.html
# API reference store plotting type to be used 
    # https://seaborn.pydata.org/api.html

# %% [markdown]
# ##  Distribution Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')
# Seaborn has a built in data set like tips

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Dist plot:
    # allows us to see distrbution of univariatnt(one variable)

# %%
sns.distplot(tips['total_bill'])
    # You will be able to see distribution of one column
    # we will be given a histogram, and a KDE
    # KDA: Kernel denisty estimation
    # histogram : distribution of your column
# Out:
# C:\Users\Abdelrahman\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],kde=False)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.distplot(tips['total_bill'],kde=False,bins=40)
    # bins to show more details
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
# Jointplot:
    # It works with two variables(combine two distribution)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)
    # x,y : the values you want to compare
    # data is your data set
# Here you can see as your bill is higher your tip will be higher

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')
    # kind to change your distribution representation 
    # default is scattered
    # hex will make a hex dist, but the plus that it gets darker if more points exist in a place

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')
    # here you can build a liner regression

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')
    # kde shows the density

# %%
# pairplot :
    # plot pair wise relationship across dataframe 
    # It will figure out every relation in data(perform joint plot on paris)
    # It will perform histogram if a variable vs itself

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex')
    # hue: you can divide your data by category

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')
    # palette to change colors

# %%
# rugplot
    # It just put more dash line intop of each other
    # Each dash line represent gaussian distribution
    # It's like displot

# %%
plt.subplot(1,2,1)
sns.rugplot(tips['total_bill'])
plt.subplot(1,2,2)
sns.distplot(tips['total_bill'],kde=False)
# Out:
# C:\Users\Abdelrahman\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill'>

# %%
# kde:
    # It's just a sum of many gaussian distribution curves
    # So, rugplot gives the place of center of gaussian
    # And, dist sums them up to get kde

# %%
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
# To get the kde plot we can sum these basis functions.

# Plot the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)

# Plot figure
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

# Add the initial rugplot
sns.rugplot(dataset,c = 'indianred')

# Get rid of y-tick marks
plt.yticks([])

# Set title
plt.suptitle("Sum of the Basis Functions")
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Functions')

# %%
# kde plot

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## Categorical Plots

# %%
# All to descripe categories

# %%
import seaborn as sns
# %matplotlib inline
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# barplot:
    # Aggregate categorical data based on some function 
    # The default function is mean

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
    # x is categories
    # y is cateogorical data
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
    # estimator used to define the function
    # std : will be used here to show the variance(standard deviation)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
# countplot: 
    # like barplot, but the estimator counts the number per category

# %%
sns.countplot(x='sex',data=tips)
    # Here you only need to define x
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# boxplot (whisker ):
    # visualising categorical data ( data can be divided into categories)
    # Used to make comparison between varialbles
    # It includes the outliers, the median, the mode, and where the majority of the data points lie in a “box”
    # The dots is the outlier
    # The median is the line

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
    # x is cateogrial
    # y is the value we compare with
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')
    # hue can be used to increase one more variable for comparison
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Violin plot:
    # It's similar to boxplot
    # It contains all the data unlike box plot
    # It shows kernel density

# %%
sns.violinplot(x='day',y='total_bill',data= tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)
    # to compare the halves of different hues just use split
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# stripplot
        # Just a scattered plot based on cateogry

# %%
sns.stripplot(x='day',y='total_bill',data=tips)
    # Same I/P as violin and boxplot
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True)
    # jitter used to show density by adding some noise to show points above each other
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips,
              hue='sex',jitter=True,dodge=True)
    # dodge do the same job, as split|
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Swarmplot:
    # Combination of violin & strip to show density
    # disadv: it won't be helpful with big data, as it spread data on x axis

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')
    # To plot both of them on top of each other
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# factorplot
    # It's a general case
    # Just chose plot type in kind(violin, bar, point, box ,strip)

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='box')
# Out:
# C:\Users\Abdelrahman\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ## Matrix Plot

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
tips=sns.load_dataset('tips')
flights=sns.load_dataset('flights')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# Heat map
    # It colors values in matrix based on gradient
    # Our data should correlate to both columns and data variable
    # So, data should be in a matirx form: 
        # To make it use correlation data, or pivot table

# %%
tc=tips.corr()
    # here we used correlation

# %%
sns.heatmap(tc)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tc,annot=True,cmap='coolwarm')
    # annotation tp show values on heat map
    # cmap to change colors
# Out:
# <AxesSubplot:>

# %%
from numpy.random import randn
index =['alex', ' cairo', 'alex','cairo']
column=['day1','day2','day1','day2']
df=pd.DataFrame(randn(4,4),index,column)

# %%
df
# Out:
#             day1      day2      day1      day2
# alex   -0.405278  1.549432 -0.415499 -0.781375
#  cairo  2.205468 -1.295929  0.295481  2.186995
# alex   -1.592648 -0.084782 -1.172019 -0.423688
# cairo  -0.868849  0.550887  1.759442 -1.433692

# %%
sns.heatmap(df,annot=True)
# Out:
# <AxesSubplot:>

# %%
pivot_flight=flights.pivot_table(index='month',columns='year',values='passengers')
    # here we used pivot table

# %%
pivot_flight
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(pivot_flight,cmap='magma',linecolor='white',linewidth=1)
    # linecolor to change seperations color
    # line width to add seperation
    # magma another cmpa
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
# Cluser map
    # Used hierarcal clustring to produce clustered version of heatmap
    # It cluster rows & columns together based on similarity

# %%
sns.clustermap(pivot_flight)

# %%
sns.clustermap(pivot_flight,cmap='coolwarm')

# %%
sns.clustermap(pivot_flight,cmap='coolwarm',standard_scale=1)
    # standard_scale will normalize our data to 1

# %% [markdown]
# ## Grids

# %%
# PariGrid
    # Pairplot is the automatic version of PariGrid
    # PairGrid has more control on the type of plot to map on data

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
    # It's measurement for some species of flowers
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
    # That is the main flowers the rest is just features
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris)

# %%
sns.PairGrid(iris)
    # It will just give you an empty grid

# %%
g=sns.PairGrid(iris)
g.map(plt.scatter)
    # It will map scatter plot to our data 
    # we just pass in the scatter function itself (define what fn to use)

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.histplot,kde=True)
    # To choose histogram for diagonal
g.map_upper(plt.scatter)
    # To choose scatter for upper 
g.map_lower(sns.kdeplot)
    # To choose kde plot for lower

# %%
# FacetGrid
    # You will divide your data based on 2 categories
    # Rather than passing numbers for col & rows you pass categories names, and the FaceGrid will get apply unique to them
#sns.FaceGrid(<data>,col='cat1',row='cat2') 
    # It will produce empty grid
    # map(<fn name>,<variable on x axis>)
        # the variable is what we want to display(map)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Dinner', 'Lunch']

# %%
tips['smoker'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']

# %%
g=sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(sns.histplot,'total_bill',kde=True)
    # Here you choosed total_bill as the variable to map hist on

# %%
g=sns.FacetGrid(tips,col='time',row='smoker')
g.map(plt.scatter,'total_bill','tip')
    # scatter needs two arrguments(I/P)

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=tips)
g = g.plot(sns.regplot, sns.histplot)

# %% [markdown]
# ## Regression Plots

# %%
# lmplot
    # allows you to display linear model with seaborn
    # It will produce scatter plot with linear fit on top of it

# %%
import seaborn as sns
# %matplotlib inline
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')
    # hue here won't cluster the data based on category, but it will make two plots with two lines to fit

# %% [markdown]
# ## Style parameter for lmplot

# %%
# Marker
    # It works with the general form 'replot' of lmplot

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue ='sex',markers=['o','v'],
          scatter_kws={'s':100})
    # markers to change symbols used for categories
    # You will pass the size as dictionary

# %%
# Grid
    # Used to seperate data by columns not colors like hue

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time')
    # you can seprate rows too

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex')
    # You can add hue too to your data
    # Here we need to play with aspect ration for figures

# %%
# aspect ratio

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',
          aspect=.6,height=8)
    # aspect ratio to change width to height
    # You still need to change color

# %% [markdown]
# ## Style & Color

# %%
# set_style, set_context
# plt.figure(figuresize=(,))
# sns.despine
# Choose palette from site

# %%
import seaborn as sns
# %matplotlib inline
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#sns.set_style('')
    # To change the style of all your plots

# %%
sns.set_style('darkgrid')
sns.set_style('whitegrid')
sns.set_style('ticks')

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#despine to remove top, and right spine

# %%
sns.countplot(x='sex',data=tips)
sns.despine()
    #sns,despine(left=True,bottom=True) to remove all spine

# %%
# size and aspect

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)
    # plt.figure will overwrite countplot figure
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# Scale & context
    # Used with sns.set_context()
    # context will change how you display you data
        # ex: as a  notebook, or poster
    # font_scale: will scale your font

# %%
sns.set_context(context='notebook',font_scale=2)
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# palette & colors
    # To choose palette:
        # https://matplotlib.org/stable/tutorials/colors/colormaps.html
    #

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex'
          ,palette='coolwarm')
